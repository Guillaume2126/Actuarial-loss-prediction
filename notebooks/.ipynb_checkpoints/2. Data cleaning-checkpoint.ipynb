# %%
Dans le notebook suivant, nous ferons les modifications suivantes:

- Les valeurs NaN sont uniquements présentes dans le statut marital, lors du processing des données, nous allons les remplacer par Unknown

- Les dates seront converties au format "datetime"

drop duplicates (yen a pas)

retirer (df_train["HoursWorkedPerWeek"] > 168).sum()

hours_per_day = (
    df_train["HoursWorkedPerWeek"] /
    df_train["DaysWorkedPerWeek"]
)

len(df_train[hours_per_day > 24])

(df_train["DateReported"] < df_train["DateTimeOfAccident"]).sum()

TF-IDF
embeddings
nettoyage NLP pour le texte de la reclamation

# %%
Feature engineering

df_train["DateTimeOfAccident"] = pd.to_datetime(
    df_train["DateTimeOfAccident"]
)

df_train["DateReported"] = pd.to_datetime(
    df_train["DateReported"]
)

df_train["ReportingDelay"] = (
    df_train["DateReported"]
    - df_train["DateTimeOfAccident"]
).dt.days
