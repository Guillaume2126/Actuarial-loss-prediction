# %%
Dire qu'on choisit RMSE car des gros outliers à gérer

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error

# %%
Entrainement dune baseline simple, puis train test split et entrainement d'un vrai modèle

# %%
from scipy import sparse
import pandas as pd

X_train = sparse.load_npz("../data/X_train.npz")
X_test = sparse.load_npz("../data/X_test.npz")

y_train = pd.read_csv("../data/y_train.csv")
